# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the data from Excel file
df = pd.read_excel("/Users/farrelmanazilin/Downloads/data/gemas.xlsx")
# Plot the time series
plt.figure(figsize=(10, 6))

# Plot Consumption Goods
plt.plot(df.index, df['Consumption Goods'], label='Consumption Goods')

# Plot Raw Material Support
plt.plot(df.index, df['Raw Material Support'], label='Raw Material Support')

# Plot Capital Goods
plt.plot(df.index, df['Capital Goods'], label='Capital Goods')

# Customize the plot
plt.xlabel('Tahun')
plt.ylabel('Value')
plt.title('Import Plot')
plt.legend()

# Display the plot
plt.show()

# %%
# Plot the time series
plt.figure(figsize=(10, 6))

# Plot MIGAS
plt.plot(df.index, df['MIGAS'], label='MIGAS')

# Plot NON MIGAS
plt.plot(df.index, df['NON MIGAS'], label='NON MIGAS')

# Plot Agriculture
plt.plot(df.index, df['Agriculture'], label='Agriculture')

# Plot Industry
plt.plot(df.index, df['Industry'], label='Industry')

# Plot Mining
plt.plot(df.index, df['Mining'], label='Mining')

# Plot Others
plt.plot(df.index, df['Others'], label='Others')

# Customize the plot
plt.xlabel('Tahun')
plt.ylabel('Value')
plt.title('Eksport Plot')
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# ses

# %%
import pandas as pd
from statsmodels.tsa.api import SimpleExpSmoothing

ins1 = SimpleExpSmoothing(data['Raw Material Support']).fit(smoothing_level=0.2,optimized=False)
ins_cast1 = ins1.forecast(3).rename('alpha=0.2')


ins3 = SimpleExpSmoothing(data['Raw Material Support']).fit()
ins_cast3 = ins3.forecast(3).rename('alpha=%s'%ins3.model.params['smoothing_level'])

#After creating model we will visualize the plot
ax = data['Raw Material Support'].plot(marker='o', color='black', figsize=(12,8), legend=True)

#Plot for alpha =0.2
ins_cast1.plot(marker='+', ax=ax, color='purple', legend=True)
ins1.fittedvalues.plot(marker='+', ax=ax, color='purple')


#Plot for alpha=Optimized by statsmodel
ins_cast3.plot(marker='*', ax=ax, color='red', legend=True)
ins3.fittedvalues.plot(marker='*', ax=ax, color='red')

plt.title('Eksport Plot Raw Material Support')

plt.show()

ins1 = SimpleExpSmoothing(data["Consumption Goods"]).fit(smoothing_level=0.2,optimized=False)
ins_cast1 = ins1.forecast(3).rename('alpha=0.2')


ins3 = SimpleExpSmoothing(data["Consumption Goods"]).fit()
ins_cast3 = ins3.forecast(3).rename('alpha=%s'%ins3.model.params['smoothing_level'])

#After creating model we will visualize the plot
ax = data["Consumption Goods"].plot(marker='o', color='black', figsize=(12,8), legend=True)

#Plot for alpha =0.2
ins_cast1.plot(marker='+', ax=ax, color='purple', legend=True)
ins1.fittedvalues.plot(marker='+', ax=ax, color='purple')


#Plot for alpha=Optimized by statsmodel
ins_cast3.plot(marker='*', ax=ax, color='red', legend=True)
ins3.fittedvalues.plot(marker='*', ax=ax, color='red')

plt.title('Eksport Plot Consumption Goods')

plt.show()

ins1 = SimpleExpSmoothing(data['Capital Goods']).fit(smoothing_level=0.2,optimized=False)
ins_cast1 = ins1.forecast(3).rename('alpha=0.2')


ins3 = SimpleExpSmoothing(data['Capital Goods']).fit()
ins_cast3 = ins3.forecast(3).rename('alpha=%s'%ins3.model.params['smoothing_level'])

#After creating model we will visualize the plot
ax = data[['Capital Goods']].plot(marker='o', color='black', figsize=(12,8), legend=True)

#Plot for alpha =0.2
ins_cast1.plot(marker='+', ax=ax, color='purple', legend=True)
ins1.fittedvalues.plot(marker='+', ax=ax, color='purple')


#Plot for alpha=Optimized by statsmodel
ins_cast3.plot(marker='*', ax=ax, color='red', legend=True)
ins3.fittedvalues.plot(marker='*', ax=ax, color='red')

plt.title('Eksport Plot Capital Goods')

plt.show()

# %%
ins1 = SimpleExpSmoothing(data['MIGAS']).fit(smoothing_level=0.2,optimized=False)
ins_cast1 = ins1.forecast(3).rename('alpha=0.2')


ins3 = SimpleExpSmoothing(data['MIGAS']).fit()
ins_cast3 = ins3.forecast(3).rename('alpha=%s'%ins3.model.params['smoothing_level'])

#After creating model we will visualize the plot
ax = data['MIGAS'].plot(marker='o', color='black', figsize=(12,8), legend=True)

#Plot for alpha =0.2
ins_cast1.plot(marker='+', ax=ax, color='purple', legend=True)
ins1.fittedvalues.plot(marker='+', ax=ax, color='purple')


#Plot for alpha=Optimized by statsmodel
ins_cast3.plot(marker='*', ax=ax, color='red', legend=True)
ins3.fittedvalues.plot(marker='*', ax=ax, color='red')

plt.title('Eksport Plot MIGAS')

plt.show()

#--------------------------------------------------------------------------------------------------------------------

ins1 = SimpleExpSmoothing(data["NON MIGAS"]).fit(smoothing_level=0.2,optimized=False)
ins_cast1 = ins1.forecast(3).rename('alpha=0.2')


ins3 = SimpleExpSmoothing(data["NON MIGAS"]).fit()
ins_cast3 = ins3.forecast(3).rename('alpha=%s'%ins3.model.params['smoothing_level'])

#After creating model we will visualize the plot
ax = data["NON MIGAS"].plot(marker='o', color='black', figsize=(12,8), legend=True)

#Plot for alpha =0.2
ins_cast1.plot(marker='+', ax=ax, color='purple', legend=True)
ins1.fittedvalues.plot(marker='+', ax=ax, color='purple')


#Plot for alpha=Optimized by statsmodel
ins_cast3.plot(marker='*', ax=ax, color='red', legend=True)
ins3.fittedvalues.plot(marker='*', ax=ax, color='red')

plt.title('Eksport Plot NON MIGAS')

plt.show()

#--------------------------------------------------------------------------------------------------------------------

ins1 = SimpleExpSmoothing(data['Agriculture']).fit(smoothing_level=0.2,optimized=False)
ins_cast1 = ins1.forecast(3).rename('alpha=0.2')


ins3 = SimpleExpSmoothing(data['Agriculture']).fit()
ins_cast3 = ins3.forecast(3).rename('alpha=%s'%ins3.model.params['smoothing_level'])

#After creating model we will visualize the plot
ax = data[['Agriculture']].plot(marker='o', color='black', figsize=(12,8), legend=True)

#Plot for alpha =0.2
ins_cast1.plot(marker='+', ax=ax, color='purple', legend=True)
ins1.fittedvalues.plot(marker='+', ax=ax, color='purple')


#Plot for alpha=Optimized by statsmodel
ins_cast3.plot(marker='*', ax=ax, color='red', legend=True)
ins3.fittedvalues.plot(marker='*', ax=ax, color='red')

plt.title('Eksport Plot Agriculture')

plt.show()

#--------------------------------------------------------------------------------------------------------------------

ins1 = SimpleExpSmoothing(data['Industry']).fit(smoothing_level=0.2,optimized=False)
ins_cast1 = ins1.forecast(3).rename('alpha=0.2')


ins3 = SimpleExpSmoothing(data['Industry']).fit()
ins_cast3 = ins3.forecast(3).rename('alpha=%s'%ins3.model.params['smoothing_level'])

#After creating model we will visualize the plot
ax = data[['Industry']].plot(marker='o', color='black', figsize=(12,8), legend=True)

#Plot for alpha =0.2
ins_cast1.plot(marker='+', ax=ax, color='purple', legend=True)
ins1.fittedvalues.plot(marker='+', ax=ax, color='purple')


#Plot for alpha=Optimized by statsmodel
ins_cast3.plot(marker='*', ax=ax, color='red', legend=True)
ins3.fittedvalues.plot(marker='*', ax=ax, color='red')

plt.title('Eksport Plot Industry')

plt.show()

#--------------------------------------------------------------------------------------------------------------------

ins1 = SimpleExpSmoothing(data['Mining']).fit(smoothing_level=0.2,optimized=False)
ins_cast1 = ins1.forecast(3).rename('alpha=0.2')


ins3 = SimpleExpSmoothing(data['Mining']).fit()
ins_cast3 = ins3.forecast(3).rename('alpha=%s'%ins3.model.params['smoothing_level'])

#After creating model we will visualize the plot
ax = data[['Mining']].plot(marker='o', color='black', figsize=(12,8), legend=True)

#Plot for alpha =0.2
ins_cast1.plot(marker='+', ax=ax, color='purple', legend=True)
ins1.fittedvalues.plot(marker='+', ax=ax, color='purple')


#Plot for alpha=Optimized by statsmodel
ins_cast3.plot(marker='*', ax=ax, color='red', legend=True)
ins3.fittedvalues.plot(marker='*', ax=ax, color='red')

plt.title('Eksport Plot Mining')

plt.show()

#--------------------------------------------------------------------------------------------------------------------

ins1 = SimpleExpSmoothing(data['Others']).fit(smoothing_level=0.2,optimized=False)
ins_cast1 = ins1.forecast(3).rename('alpha=0.2')


ins3 = SimpleExpSmoothing(data['Others']).fit()
ins_cast3 = ins3.forecast(3).rename('alpha=%s'%ins3.model.params['smoothing_level'])

#After creating model we will visualize the plot
ax = data[['Others']].plot(marker='o', color='black', figsize=(12,8), legend=True)

#Plot for alpha =0.2
ins_cast1.plot(marker='+', ax=ax, color='purple', legend=True)
ins1.fittedvalues.plot(marker='+', ax=ax, color='purple')


#Plot for alpha=Optimized by statsmodel
ins_cast3.plot(marker='*', ax=ax, color='red', legend=True)
ins3.fittedvalues.plot(marker='*', ax=ax, color='red')

plt.title('Eksport Plot Others')

plt.show()

# %% [markdown]
# linear regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# Read the data from Excel file
df = pd.read_excel("/Users/farrelmanazilin/Downloads/data/gemas.xlsx")

# Extract the independent variable (X) and dependent variable (y)
X = df.index.values.reshape(-1, 1)  # Use the index as the independent variable
y = df['Consumption Goods']  # Use 'Consumption Goods' as the dependent variable

# Create and fit the linear regression model
regression_model = LinearRegression()
regression_model.fit(X, y)

# Get the coefficient and intercept of the linear regression model
coefficient = regression_model.coef_[0]
intercept = regression_model.intercept_

# Make predictions using the linear regression model
y_pred = regression_model.predict(X)

# Calculate the R-squared score
r_squared = r2_score(y, y_pred)

# Calculate the number of observations and number of features
n_obs = len(X)
n_features = regression_model.coef_.shape[0]

# Calculate the Adjusted R-squared score
adjusted_r_squared = 1 - (1 - r_squared) * (n_obs - 1) / (n_obs - n_features - 1)

# Calculate the residuals
residuals = y - y_pred

# Calculate the standard error (SE)
se = (mean_squared_error(y, y_pred)) ** 0.5

# Calculate the root mean square error (RMSE)
rmse = mean_squared_error(y, y_pred, squared=False)

# Calculate the mean absolute error (MAE)
mae = mean_absolute_error(y, y_pred)

# Calculate the root relative squared error (RRSE)
rrse = (rmse / (y.max() - y.min())) * 100

# Calculate the relative absolute error (RAE)
rae = (mae / (y.max() - y.min())) * 100

# Print the evaluation metrics
print("R-squared (R²):", r_squared)
print("Adjusted R-squared (R²):", adjusted_r_squared)
print("Residuals:", residuals)
print("Standard Error (SE):", se)
print("Root Mean Square Error (RMSE):", rmse)
print("Mean Absolute Error (MAE):", mae)
print("Root Relative Squared Error (RRSE):", rrse)
print("Relative Absolute Error (RAE):", rae)
print("Coefficient:", coefficient)
print("Intercept:", intercept)

# Plot the regression line
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue', label='Actual')
plt.plot(X, y_pred, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('Tahun')
plt.ylabel('Value')
plt.title('Linear Regression Import Consumption Goods')
plt.legend()
plt.show()
# Out:
# R-squared (R²): 0.31014491788354626
# Adjusted R-squared (R²): 0.30069484826551274
# Residuals: 0    -140.604211
# 1    -273.021999
# 2     160.350212
# 3     -80.837577
# 4     104.984634
#          ...
# 70      4.690566
# 71    126.672777
# 72    -91.075012
# 73   -330.632801
# 74     59.319411
# Name: Consumption Goods, Length: 75, dtype: float64
# Standard Error (SE): 239.17579736312987
# Root Mean Square Error (RMSE): 239.17579736312987
# Mean Absolute Error (MAE): 182.16485746040777
# Root Relative Squared Error (RRSE): 14.867829360912669
# Relative Absolute Error (RAE): 11.32387158791107
# Coefficient: 7.4077889046941685
# Intercept: 1153.9542105263156

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# Read the data from Excel file
df = pd.read_excel("/Users/farrelmanazilin/Downloads/data/gemas.xlsx")

# Extract the independent variable (X) and dependent variable (y)
X = df.index.values.reshape(-1, 1)  # Use the index as the independent variable
y = df['Raw Material Support']  # Use 'Raw Material Support' as the dependent variable

# Create and fit the linear regression model
regression_model = LinearRegression()
regression_model.fit(X, y)

# Get the coefficient and intercept of the linear regression model
coefficient = regression_model.coef_[0]
intercept = regression_model.intercept_

# Make predictions using the linear regression model
y_pred = regression_model.predict(X)

# Calculate the R-squared score
r_squared = r2_score(y, y_pred)

# Calculate the number of observations and number of features
n_obs = len(X)
n_features = regression_model.coef_.shape[0]

# Calculate the Adjusted R-squared score
adjusted_r_squared = 1 - (1 - r_squared) * (n_obs - 1) / (n_obs - n_features - 1)

# Calculate the residuals
residuals = y - y_pred

# Calculate the standard error (SE)
se = (mean_squared_error(y, y_pred)) ** 0.5

# Calculate the root mean square error (RMSE)
rmse = mean_squared_error(y, y_pred, squared=False)

# Calculate the mean absolute error (MAE)
mae = mean_absolute_error(y, y_pred)

# Calculate the root relative squared error (RRSE)
rrse = (rmse / (y.max() - y.min())) * 100

# Calculate the relative absolute error (RAE)
rae = (mae / (y.max() - y.min())) * 100

# Print the evaluation metrics
print("R-squared (R²):", r_squared)
print("Adjusted R-squared (R²):", adjusted_r_squared)
print("Residuals:", residuals)
print("Standard Error (SE):", se)
print("Root Mean Square Error (RMSE):", rmse)
print("Mean Absolute Error (MAE):", mae)
print("Root Relative Squared Error (RRSE):", rrse)
print("Relative Absolute Error (RAE):", rae)
print("Coefficient:", coefficient)
print("Intercept:", intercept)

# Plot the regression line
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue', label='Actual')
plt.plot(X, y_pred, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('Tahun')
plt.ylabel('Value')
plt.title('Linear Regression Import Raw Material Support')
plt.legend()
plt.show()
# Out:
# R-squared (R²): 0.3056515166042385
# Adjusted R-squared (R²): 0.2961398935440226
# Residuals: 0      -74.074814
# 1     -409.419415
# 2      701.985983
# 3     -303.468618
# 4     1160.056780
#          ...
# 70     569.283086
# 71     863.988485
# 72     262.993884
# 73   -1894.000718
# 74    1366.224681
# Name: Raw Material Support, Length: 75, dtype: float64
# Standard Error (SE): 2023.4918421844968
# Root Mean Square Error (RMSE): 2023.4918421844968
# Mean Absolute Error (MAE): 1581.8877211544175
# Root Relative Squared Error (RRSE): 18.556314236051726
# Relative Absolute Error (RAE): 14.506609331423595
# Coefficient: 62.0146014224751
# Intercept: 9158.854814035089

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# Read the data from Excel file
df = pd.read_excel("/Users/farrelmanazilin/Downloads/data/gemas.xlsx")

# Extract the independent variable (X) and dependent variable (y)
X = df.index.values.reshape(-1, 1)  # Use the index as the independent variable
y = df['Capital Goods']  # Use 'Capital Goods' as the dependent variable

# Create and fit the linear regression model
regression_model = LinearRegression()
regression_model.fit(X, y)

# Get the coefficient and intercept of the linear regression model
coefficient = regression_model.coef_[0]
intercept = regression_model.intercept_

# Make predictions using the linear regression model
y_pred = regression_model.predict(X)

# Calculate the R-squared score
r_squared = r2_score(y, y_pred)

# Calculate the number of observations and number of features
n_obs = len(X)
n_features = regression_model.coef_.shape[0]

# Calculate the Adjusted R-squared score
adjusted_r_squared = 1 - (1 - r_squared) * (n_obs - 1) / (n_obs - n_features - 1)

# Calculate the residuals
residuals = y - y_pred

# Calculate the standard error (SE)
se = (mean_squared_error(y, y_pred)) ** 0.5

# Calculate the root mean square error (RMSE)
rmse = mean_squared_error(y, y_pred, squared=False)

# Calculate the mean absolute error (MAE)
mae = mean_absolute_error(y, y_pred)

# Calculate the root relative squared error (RRSE)
rrse = (rmse / (y.max() - y.min())) * 100

# Calculate the relative absolute error (RAE)
rae = (mae / (y.max() - y.min())) * 100

# Print the evaluation metrics
print("R-squared (R²):", r_squared)
print("Adjusted R-squared (R²):", adjusted_r_squared)
print("Residuals:", residuals)
print("Standard Error (SE):", se)
print("Root Mean Square Error (RMSE):", rmse)
print("Mean Absolute Error (MAE):", mae)
print("Root Relative Squared Error (RRSE):", rrse)
print("Relative Absolute Error (RAE):", rae)
print("Coefficient:", coefficient)
print("Intercept:", intercept)

# Plot the regression line
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue', label='Actual')
plt.plot(X, y_pred, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('Tahun')
plt.ylabel('Value')
plt.title('Linear Regression Import Capital Goods')
plt.legend()
plt.show()
# Out:
# R-squared (R²): 0.2903255124825006
# Adjusted R-squared (R²): 0.28060394416034307
# Residuals: 0     -81.994379
# 1    -310.328109
# 2     -13.091840
# 3    -180.755570
# 4     -89.909300
#          ...
# 70    395.444500
# 71    797.980770
# 72    114.847040
# 73    -94.106691
# 74    842.849579
# Name: Capital Goods, Length: 75, dtype: float64
# Standard Error (SE): 417.1201923227282
# Root Mean Square Error (RMSE): 417.1201923227282
# Mean Absolute Error (MAE): 341.3274496121384
# Root Relative Squared Error (RRSE): 17.988933409353628
# Relative Absolute Error (RAE): 14.720257793481792
# Coefficient: 12.323730298719772
# Intercept: 1957.6343789473685

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# Read the data from Excel file
df = pd.read_excel("/Users/farrelmanazilin/Downloads/data/gemas.xlsx")

# Extract the independent variable (X) and dependent variable (y)
X = df.index.values.reshape(-1, 1)  # Use the index as the independent variable
y = df['MIGAS']  # Use 'MIGAS' as the dependent variable

# Create and fit the linear regression model
regression_model = LinearRegression()
regression_model.fit(X, y)

# Get the coefficient and intercept of the linear regression model
coefficient = regression_model.coef_[0]
intercept = regression_model.intercept_

# Make predictions using the linear regression model
y_pred = regression_model.predict(X)

# Calculate the R-squared score
r_squared = r2_score(y, y_pred)

# Calculate the number of observations and number of features
n_obs = len(X)
n_features = regression_model.coef_.shape[0]

# Calculate the Adjusted R-squared score
adjusted_r_squared = 1 - (1 - r_squared) * (n_obs - 1) / (n_obs - n_features - 1)

# Calculate the residuals
residuals = y - y_pred

# Calculate the standard error (SE)
se = (mean_squared_error(y, y_pred)) ** 0.5

# Calculate the root mean square error (RMSE)
rmse = mean_squared_error(y, y_pred, squared=False)

# Calculate the mean absolute error (MAE)
mae = mean_absolute_error(y, y_pred)

# Calculate the root relative squared error (RRSE)
rrse = (rmse / (y.max() - y.min())) * 100

# Calculate the relative absolute error (RAE)
rae = (mae / (y.max() - y.min())) * 100

# Print the evaluation metrics
print("R-squared (R²):", r_squared)
print("Adjusted R-squared (R²):", adjusted_r_squared)
print("Residuals:", residuals)
print("Standard Error (SE):", se)
print("Root Mean Square Error (RMSE):", rmse)
print("Mean Absolute Error (MAE):", mae)
print("Root Relative Squared Error (RRSE):", rrse)
print("Relative Absolute Error (RAE):", rae)
print("Coefficient:", coefficient)
print("Intercept:", intercept)

# Plot the regression line
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue', label='Actual')
plt.plot(X, y_pred, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('Tahun')
plt.ylabel('Value')
plt.title('Linear Regression Eksport MIGAS')
plt.legend()
plt.show()
# Out:
# R-squared (R²): 0.01817091410190841
# Adjusted R-squared (R²): 0.0047212005964550885
# Residuals: 0      71.936818
# 1       3.892745
# 2     313.398672
# 3    -164.705400
# 4      95.340527
#          ...
# 70     40.231739
# 71    400.787667
# 72    417.823594
# 73    118.279522
# 74    271.895449
# Name: MIGAS, Length: 75, dtype: float64
# Standard Error (SE): 301.7055556795659
# Root Mean Square Error (RMSE): 301.7055556795659
# Mean Absolute Error (MAE): 251.41379565165164
# Root Relative Squared Error (RRSE): 26.32867527223243
# Relative Absolute Error (RAE): 21.939908165635615
# Coefficient: -1.8959274537695592
# Intercept: 1206.6331824561403

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# Read the data from Excel file
df = pd.read_excel("/Users/farrelmanazilin/Downloads/data/gemas.xlsx")

# Extract the independent variable (X) and dependent variable (y)
X = df.index.values.reshape(-1, 1)  # Use the index as the independent variable
y = df['NON MIGAS']  # Use 'NON MIGAS' as the dependent variable

# Create and fit the linear regression model
regression_model = LinearRegression()
regression_model.fit(X, y)

# Get the coefficient and intercept of the linear regression model
coefficient = regression_model.coef_[0]
intercept = regression_model.intercept_

# Make predictions using the linear regression model
y_pred = regression_model.predict(X)

# Calculate the R-squared score
r_squared = r2_score(y, y_pred)

# Calculate the number of observations and number of features
n_obs = len(X)
n_features = regression_model.coef_.shape[0]

# Calculate the Adjusted R-squared score
adjusted_r_squared = 1 - (1 - r_squared) * (n_obs - 1) / (n_obs - n_features - 1)

# Calculate the residuals
residuals = y - y_pred

# Calculate the standard error (SE)
se = (mean_squared_error(y, y_pred)) ** 0.5

# Calculate the root mean square error (RMSE)
rmse = mean_squared_error(y, y_pred, squared=False)

# Calculate the mean absolute error (MAE)
mae = mean_absolute_error(y, y_pred)

# Calculate the root relative squared error (RRSE)
rrse = (rmse / (y.max() - y.min())) * 100

# Calculate the relative absolute error (RAE)
rae = (mae / (y.max() - y.min())) * 100

# Print the evaluation metrics
print("R-squared (R²):", r_squared)
print("Adjusted R-squared (R²):", adjusted_r_squared)
print("Residuals:", residuals)
print("Standard Error (SE):", se)
print("Root Mean Square Error (RMSE):", rmse)
print("Mean Absolute Error (MAE):", mae)
print("Root Relative Squared Error (RRSE):", rrse)
print("Relative Absolute Error (RAE):", rae)
print("Coefficient:", coefficient)
print("Intercept:", intercept)

# Plot the regression line
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue', label='Actual')
plt.plot(X, y_pred, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('Tahun')
plt.ylabel('Value')
plt.title('Linear Regression Eksport NON MIGAS')
plt.legend()
plt.show()
# Out:
# R-squared (R²): 0.6376057583412004
# Adjusted R-squared (R²): 0.6326414536609428
# Residuals: 0     2093.931495
# 1     1226.058438
# 2     2864.825382
# 3     1739.912325
# 4     2389.809268
#          ...
# 70    2026.107532
# 71    1245.144475
# 72    -430.138582
# 73   -1287.391638
# 74     499.495305
# Name: NON MIGAS, Length: 75, dtype: float64
# Standard Error (SE): 2548.083216075449
# Root Mean Square Error (RMSE): 2548.083216075449
# Mean Absolute Error (MAE): 2106.4134235372217
# Root Relative Squared Error (RRSE): 15.647945114079183
# Relative Absolute Error (RAE): 12.935622130048241
# Coefficient: 156.12305661450927
# Intercept: 10025.168505263158

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# Read the data from Excel file
df = pd.read_excel("/Users/farrelmanazilin/Downloads/data/gemas.xlsx")

# Extract the independent variable (X) and dependent variable (y)
X = df.index.values.reshape(-1, 1)  # Use the index as the independent variable
y = df['Agriculture']  # Use 'Agriculture' as the dependent variable

# Create and fit the linear regression model
regression_model = LinearRegression()
regression_model.fit(X, y)

# Get the coefficient and intercept of the linear regression model
coefficient = regression_model.coef_[0]
intercept = regression_model.intercept_

# Make predictions using the linear regression model
y_pred = regression_model.predict(X)

# Calculate the R-squared score
r_squared = r2_score(y, y_pred)

# Calculate the number of observations and number of features
n_obs = len(X)
n_features = regression_model.coef_.shape[0]

# Calculate the Adjusted R-squared score
adjusted_r_squared = 1 - (1 - r_squared) * (n_obs - 1) / (n_obs - n_features - 1)

# Calculate the residuals
residuals = y - y_pred

# Calculate the standard error (SE)
se = (mean_squared_error(y, y_pred)) ** 0.5

# Calculate the root mean square error (RMSE)
rmse = mean_squared_error(y, y_pred, squared=False)

# Calculate the mean absolute error (MAE)
mae = mean_absolute_error(y, y_pred)

# Calculate the root relative squared error (RRSE)
rrse = (rmse / (y.max() - y.min())) * 100

# Calculate the relative absolute error (RAE)
rae = (mae / (y.max() - y.min())) * 100

# Print the evaluation metrics
print("R-squared (R²):", r_squared)
print("Adjusted R-squared (R²):", adjusted_r_squared)
print("Residuals:", residuals)
print("Standard Error (SE):", se)
print("Root Mean Square Error (RMSE):", rmse)
print("Mean Absolute Error (MAE):", mae)
print("Root Relative Squared Error (RRSE):", rrse)
print("Relative Absolute Error (RAE):", rae)
print("Coefficient:", coefficient)
print("Intercept:", intercept)

# Plot the regression line
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue', label='Actual')
plt.plot(X, y_pred, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('Tahun')
plt.ylabel('Value')
plt.title('Linear Regression Eksport Agriculture')
plt.legend()
plt.show()
# Out:
# R-squared (R²): 0.3755731641508261
# Adjusted R-squared (R²): 0.36701937187891964
# Residuals: 0     10.835000
# 1      9.211827
# 2     18.048654
# 3      3.455481
# 4     38.752308
#         ...
# 70    33.712892
# 71   -17.960281
# 72   -15.903454
# 73   -53.616627
# 74   -15.479800
# Name: Agriculture, Length: 75, dtype: float64
# Standard Error (SE): 46.70532267830214
# Root Mean Square Error (RMSE): 46.70532267830214
# Mean Absolute Error (MAE): 36.26788598198198
# Root Relative Squared Error (RRSE): 18.57218175532931
# Relative Absolute Error (RAE): 14.421777470169392
# Coefficient: 1.6731729729729723
# Intercept: 269.485

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# Read the data from Excel file
df = pd.read_excel("/Users/farrelmanazilin/Downloads/data/gemas.xlsx")

# Extract the independent variable (X) and dependent variable (y)
X = df.index.values.reshape(-1, 1)  # Use the index as the independent variable
y = df['Industry']  # Use 'Industry' as the dependent variable

# Create and fit the linear regression model
regression_model = LinearRegression()
regression_model.fit(X, y)

# Get the coefficient and intercept of the linear regression model
coefficient = regression_model.coef_[0]
intercept = regression_model.intercept_

# Make predictions using the linear regression model
y_pred = regression_model.predict(X)

# Calculate the R-squared score
r_squared = r2_score(y, y_pred)

# Calculate the number of observations and number of features
n_obs = len(X)
n_features = regression_model.coef_.shape[0]

# Calculate the Adjusted R-squared score
adjusted_r_squared = 1 - (1 - r_squared) * (n_obs - 1) / (n_obs - n_features - 1)

# Calculate the residuals
residuals = y - y_pred

# Calculate the standard error (SE)
se = (mean_squared_error(y, y_pred)) ** 0.5

# Calculate the root mean square error (RMSE)
rmse = mean_squared_error(y, y_pred, squared=False)

# Calculate the mean absolute error (MAE)
mae = mean_absolute_error(y, y_pred)

# Calculate the root relative squared error (RRSE)
rrse = (rmse / (y.max() - y.min())) * 100

# Calculate the relative absolute error (RAE)
rae = (mae / (y.max() - y.min())) * 100

# Print the evaluation metrics
print("R-squared (R²):", r_squared)
print("Adjusted R-squared (R²):", adjusted_r_squared)
print("Residuals:", residuals)
print("Standard Error (SE):", se)
print("Root Mean Square Error (RMSE):", rmse)
print("Mean Absolute Error (MAE):", mae)
print("Root Relative Squared Error (RRSE):", rrse)
print("Relative Absolute Error (RAE):", rae)
print("Coefficient:", coefficient)
print("Intercept:", intercept)

# Plot the regression line
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue', label='Actual')
plt.plot(X, y_pred, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('Tahun')
plt.ylabel('Value')
plt.title('Linear Regression Eksport Industry')
plt.legend()
plt.show()
# Out:
# R-squared (R²): 0.6631573680328755
# Adjusted R-squared (R²): 0.6585430854031888
# Residuals: 0     1368.110923
# 1     1095.212058
# 2     2282.253194
# 3     1027.404329
# 4     1811.705464
#          ...
# 70     442.880402
# 71     220.901538
# 72    -489.817327
# 73   -1050.986192
# 74      22.914944
# Name: Industry, Length: 75, dtype: float64
# Standard Error (SE): 1719.2338946117447
# Root Mean Square Error (RMSE): 1719.2338946117447
# Mean Absolute Error (MAE): 1412.4455358305675
# Root Relative Squared Error (RRSE): 14.557972005854102
# Relative Absolute Error (RAE): 11.960177515612907
# Coefficient: 111.42886458036983
# Intercept: 8667.729077192984

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# Read the data from Excel file
df = pd.read_excel("/Users/farrelmanazilin/Downloads/data/gemas.xlsx")

# Extract the independent variable (X) and dependent variable (y)
X = df.index.values.reshape(-1, 1)  # Use the index as the independent variable
y = df['Mining']  # Use 'Mining' as the dependent variable

# Create and fit the linear regression model
regression_model = LinearRegression()
regression_model.fit(X, y)

# Get the coefficient and intercept of the linear regression model
coefficient = regression_model.coef_[0]
intercept = regression_model.intercept_

# Make predictions using the linear regression model
y_pred = regression_model.predict(X)

# Calculate the R-squared score
r_squared = r2_score(y, y_pred)

# Calculate the number of observations and number of features
n_obs = len(X)
n_features = regression_model.coef_.shape[0]

# Calculate the Adjusted R-squared score
adjusted_r_squared = 1 - (1 - r_squared) * (n_obs - 1) / (n_obs - n_features - 1)

# Calculate the residuals
residuals = y - y_pred

# Calculate the standard error (SE)
se = (mean_squared_error(y, y_pred)) ** 0.5

# Calculate the root mean square error (RMSE)
rmse = mean_squared_error(y, y_pred, squared=False)

# Calculate the mean absolute error (MAE)
mae = mean_absolute_error(y, y_pred)

# Calculate the root relative squared error (RRSE)
rrse = (rmse / (y.max() - y.min())) * 100

# Calculate the relative absolute error (RAE)
rae = (mae / (y.max() - y.min())) * 100

# Print the evaluation metrics
print("R-squared (R²):", r_squared)
print("Adjusted R-squared (R²):", adjusted_r_squared)
print("Residuals:", residuals)
print("Standard Error (SE):", se)
print("Root Mean Square Error (RMSE):", rmse)
print("Mean Absolute Error (MAE):", mae)
print("Root Relative Squared Error (RRSE):", rrse)
print("Relative Absolute Error (RAE):", rae)
print("Coefficient:", coefficient)
print("Intercept:", intercept)

# Plot the regression line
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue', label='Actual')
plt.plot(X, y_pred, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('Tahun')
plt.ylabel('Value')
plt.title('Linear Regression Eksport Mining')
plt.legend()
plt.show()
# Out:
# R-squared (R²): 0.34573253156927675
# Adjusted R-squared (R²): 0.3367699635085819
# Residuals: 0      782.769863
# 1      119.563164
# 2      877.036465
# 3      543.749766
# 4      636.363067
#          ...
# 70    1589.510933
# 71    1441.214234
# 72     492.847535
# 73     -65.219164
# 74     763.314137
# Name: Mining, Length: 75, dtype: float64
# Standard Error (SE): 1227.1775413111473
# Root Mean Square Error (RMSE): 1227.1775413111473
# Mean Absolute Error (MAE): 1039.8848692498814
# Root Relative Squared Error (RRSE): 22.10019722177765
# Relative Absolute Error (RAE): 18.727250071583494
# Coefficient: 41.20669900426743
# Intercept: 2288.760136842105

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# Read the data from Excel file
df = pd.read_excel("/Users/farrelmanazilin/Downloads/data/gemas.xlsx")

# Extract the independent variable (X) and dependent variable (y)
X = df.index.values.reshape(-1, 1)  # Use the index as the independent variable
y = df['Others']  # Use 'Others' as the dependent variable

# Create and fit the linear regression model
regression_model = LinearRegression()
regression_model.fit(X, y)

# Get the coefficient and intercept of the linear regression model
coefficient = regression_model.coef_[0]
intercept = regression_model.intercept_

# Make predictions using the linear regression model
y_pred = regression_model.predict(X)

# Calculate the R-squared score
r_squared = r2_score(y, y_pred)

# Calculate the number of observations and number of features
n_obs = len(X)
n_features = regression_model.coef_.shape[0]

# Calculate the Adjusted R-squared score
adjusted_r_squared = 1 - (1 - r_squared) * (n_obs - 1) / (n_obs - n_features - 1)

# Calculate the residuals
residuals = y - y_pred

# Calculate the standard error (SE)
se = (mean_squared_error(y, y_pred)) ** 0.5

# Calculate the root mean square error (RMSE)
rmse = mean_squared_error(y, y_pred, squared=False)

# Calculate the mean absolute error (MAE)
mae = mean_absolute_error(y, y_pred)

# Calculate the root relative squared error (RRSE)
rrse = (rmse / (y.max() - y.min())) * 100

# Calculate the relative absolute error (RAE)
rae = (mae / (y.max() - y.min())) * 100

# Print the evaluation metrics
print("R-squared (R²):", r_squared)
print("Adjusted R-squared (R²):", adjusted_r_squared)
print("Residuals:", residuals)
print("Standard Error (SE):", se)
print("Root Mean Square Error (RMSE):", rmse)
print("Mean Absolute Error (MAE):", mae)
print("Root Relative Squared Error (RRSE):", rrse)
print("Relative Absolute Error (RAE):", rae)
print("Coefficient:", coefficient)
print("Intercept:", intercept)

# Plot the regression line
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue', label='Actual')
plt.plot(X, y_pred, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('Tahun')
plt.ylabel('Value')
plt.title('Linear Regression Eksport Others')
plt.legend()
plt.show()
# Out:
# R-squared (R²): 0.16025704205449776
# Adjusted R-squared (R²): 0.14875371386346348
# Residuals: 0     4.150874
# 1     5.962547
# 2     0.884221
# 3     0.605895
# 4    -1.672432
#         ...
# 70    0.228032
# 71    1.769705
# 72    0.561379
# 73    0.723053
# 74    0.634726
# Name: Others, Length: 75, dtype: float64
# Standard Error (SE): 4.047424941297688
# Root Mean Square Error (RMSE): 4.047424941297688
# Mean Absolute Error (MAE): 2.629818947368421
# Root Relative Squared Error (RRSE): 20.992867952788842
# Relative Absolute Error (RAE): 13.640139768508408
# Coefficient: -0.0816736842105263
# Intercept: 5.829126315789473
