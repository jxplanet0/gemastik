# %% [markdown]
# ses

# %%
import pandas as pd
from statsmodels.tsa.api import SimpleExpSmoothing

ins1 = SimpleExpSmoothing(data['Raw Material Support']).fit(smoothing_level=0.2,optimized=False)
ins_cast1 = ins1.forecast(3).rename('alpha=0.2')


ins3 = SimpleExpSmoothing(data['Raw Material Support']).fit()
ins_cast3 = ins3.forecast(3).rename('alpha=%s'%ins3.model.params['smoothing_level'])

#After creating model we will visualize the plot
ax = data['Raw Material Support'].plot(marker='o', color='black', figsize=(12,8), legend=True)

#Plot for alpha =0.2
ins_cast1.plot(marker='+', ax=ax, color='purple', legend=True)
ins1.fittedvalues.plot(marker='+', ax=ax, color='purple')


#Plot for alpha=Optimized by statsmodel
ins_cast3.plot(marker='*', ax=ax, color='red', legend=True)
ins3.fittedvalues.plot(marker='*', ax=ax, color='red')

plt.title('Eksport Plot Raw Material Support')

plt.show()

ins1 = SimpleExpSmoothing(data["Consumption Goods"]).fit(smoothing_level=0.2,optimized=False)
ins_cast1 = ins1.forecast(3).rename('alpha=0.2')


ins3 = SimpleExpSmoothing(data["Consumption Goods"]).fit()
ins_cast3 = ins3.forecast(3).rename('alpha=%s'%ins3.model.params['smoothing_level'])

#After creating model we will visualize the plot
ax = data["Consumption Goods"].plot(marker='o', color='black', figsize=(12,8), legend=True)

#Plot for alpha =0.2
ins_cast1.plot(marker='+', ax=ax, color='purple', legend=True)
ins1.fittedvalues.plot(marker='+', ax=ax, color='purple')


#Plot for alpha=Optimized by statsmodel
ins_cast3.plot(marker='*', ax=ax, color='red', legend=True)
ins3.fittedvalues.plot(marker='*', ax=ax, color='red')

plt.title('Eksport Plot Consumption Goods')

plt.show()

ins1 = SimpleExpSmoothing(data['Capital Goods']).fit(smoothing_level=0.2,optimized=False)
ins_cast1 = ins1.forecast(3).rename('alpha=0.2')


ins3 = SimpleExpSmoothing(data['Capital Goods']).fit()
ins_cast3 = ins3.forecast(3).rename('alpha=%s'%ins3.model.params['smoothing_level'])

#After creating model we will visualize the plot
ax = data[['Capital Goods']].plot(marker='o', color='black', figsize=(12,8), legend=True)

#Plot for alpha =0.2
ins_cast1.plot(marker='+', ax=ax, color='purple', legend=True)
ins1.fittedvalues.plot(marker='+', ax=ax, color='purple')


#Plot for alpha=Optimized by statsmodel
ins_cast3.plot(marker='*', ax=ax, color='red', legend=True)
ins3.fittedvalues.plot(marker='*', ax=ax, color='red')

plt.title('Eksport Plot Capital Goods')

plt.show()

# %%
ins1 = SimpleExpSmoothing(data['MIGAS']).fit(smoothing_level=0.2,optimized=False)
ins_cast1 = ins1.forecast(3).rename('alpha=0.2')


ins3 = SimpleExpSmoothing(data['MIGAS']).fit()
ins_cast3 = ins3.forecast(3).rename('alpha=%s'%ins3.model.params['smoothing_level'])

#After creating model we will visualize the plot
ax = data['MIGAS'].plot(marker='o', color='black', figsize=(12,8), legend=True)

#Plot for alpha =0.2
ins_cast1.plot(marker='+', ax=ax, color='purple', legend=True)
ins1.fittedvalues.plot(marker='+', ax=ax, color='purple')


#Plot for alpha=Optimized by statsmodel
ins_cast3.plot(marker='*', ax=ax, color='red', legend=True)
ins3.fittedvalues.plot(marker='*', ax=ax, color='red')

plt.title('Eksport Plot MIGAS')

plt.show()

#--------------------------------------------------------------------------------------------------------------------

ins1 = SimpleExpSmoothing(data["NON MIGAS"]).fit(smoothing_level=0.2,optimized=False)
ins_cast1 = ins1.forecast(3).rename('alpha=0.2')


ins3 = SimpleExpSmoothing(data["NON MIGAS"]).fit()
ins_cast3 = ins3.forecast(3).rename('alpha=%s'%ins3.model.params['smoothing_level'])

#After creating model we will visualize the plot
ax = data["NON MIGAS"].plot(marker='o', color='black', figsize=(12,8), legend=True)

#Plot for alpha =0.2
ins_cast1.plot(marker='+', ax=ax, color='purple', legend=True)
ins1.fittedvalues.plot(marker='+', ax=ax, color='purple')


#Plot for alpha=Optimized by statsmodel
ins_cast3.plot(marker='*', ax=ax, color='red', legend=True)
ins3.fittedvalues.plot(marker='*', ax=ax, color='red')

plt.title('Eksport Plot NON MIGAS')

plt.show()

#--------------------------------------------------------------------------------------------------------------------

ins1 = SimpleExpSmoothing(data['Agriculture']).fit(smoothing_level=0.2,optimized=False)
ins_cast1 = ins1.forecast(3).rename('alpha=0.2')


ins3 = SimpleExpSmoothing(data['Agriculture']).fit()
ins_cast3 = ins3.forecast(3).rename('alpha=%s'%ins3.model.params['smoothing_level'])

#After creating model we will visualize the plot
ax = data[['Agriculture']].plot(marker='o', color='black', figsize=(12,8), legend=True)

#Plot for alpha =0.2
ins_cast1.plot(marker='+', ax=ax, color='purple', legend=True)
ins1.fittedvalues.plot(marker='+', ax=ax, color='purple')


#Plot for alpha=Optimized by statsmodel
ins_cast3.plot(marker='*', ax=ax, color='red', legend=True)
ins3.fittedvalues.plot(marker='*', ax=ax, color='red')

plt.title('Eksport Plot Agriculture')

plt.show()

#--------------------------------------------------------------------------------------------------------------------

ins1 = SimpleExpSmoothing(data['Industry']).fit(smoothing_level=0.2,optimized=False)
ins_cast1 = ins1.forecast(3).rename('alpha=0.2')


ins3 = SimpleExpSmoothing(data['Industry']).fit()
ins_cast3 = ins3.forecast(3).rename('alpha=%s'%ins3.model.params['smoothing_level'])

#After creating model we will visualize the plot
ax = data[['Industry']].plot(marker='o', color='black', figsize=(12,8), legend=True)

#Plot for alpha =0.2
ins_cast1.plot(marker='+', ax=ax, color='purple', legend=True)
ins1.fittedvalues.plot(marker='+', ax=ax, color='purple')


#Plot for alpha=Optimized by statsmodel
ins_cast3.plot(marker='*', ax=ax, color='red', legend=True)
ins3.fittedvalues.plot(marker='*', ax=ax, color='red')

plt.title('Eksport Plot Industry')

plt.show()

#--------------------------------------------------------------------------------------------------------------------

ins1 = SimpleExpSmoothing(data['Mining']).fit(smoothing_level=0.2,optimized=False)
ins_cast1 = ins1.forecast(3).rename('alpha=0.2')


ins3 = SimpleExpSmoothing(data['Mining']).fit()
ins_cast3 = ins3.forecast(3).rename('alpha=%s'%ins3.model.params['smoothing_level'])

#After creating model we will visualize the plot
ax = data[['Mining']].plot(marker='o', color='black', figsize=(12,8), legend=True)

#Plot for alpha =0.2
ins_cast1.plot(marker='+', ax=ax, color='purple', legend=True)
ins1.fittedvalues.plot(marker='+', ax=ax, color='purple')


#Plot for alpha=Optimized by statsmodel
ins_cast3.plot(marker='*', ax=ax, color='red', legend=True)
ins3.fittedvalues.plot(marker='*', ax=ax, color='red')

plt.title('Eksport Plot Mining')

plt.show()

#--------------------------------------------------------------------------------------------------------------------

ins1 = SimpleExpSmoothing(data['Others']).fit(smoothing_level=0.2,optimized=False)
ins_cast1 = ins1.forecast(3).rename('alpha=0.2')


ins3 = SimpleExpSmoothing(data['Others']).fit()
ins_cast3 = ins3.forecast(3).rename('alpha=%s'%ins3.model.params['smoothing_level'])

#After creating model we will visualize the plot
ax = data[['Others']].plot(marker='o', color='black', figsize=(12,8), legend=True)

#Plot for alpha =0.2
ins_cast1.plot(marker='+', ax=ax, color='purple', legend=True)
ins1.fittedvalues.plot(marker='+', ax=ax, color='purple')


#Plot for alpha=Optimized by statsmodel
ins_cast3.plot(marker='*', ax=ax, color='red', legend=True)
ins3.fittedvalues.plot(marker='*', ax=ax, color='red')

plt.title('Eksport Plot Others')

plt.show()
